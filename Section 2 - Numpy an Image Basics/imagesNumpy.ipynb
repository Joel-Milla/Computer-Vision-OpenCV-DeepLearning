# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from PIL import Image

# %%
path = 'C:/Users/jAlej/Documents/Learning/External Learning/Machine Learning/Computer Vision/Computer Vision with OpenCV and DeepLearning - udemy/Computer-Vision-with-Python/Computer-Vision-with-Python/DATA'

# %%
pic = Image.open(path+'/00-puppy.jpg')

# %%
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
pic_arr = np.asarray(pic)

# %%
type(pic_arr)
# Out:
# numpy.ndarray

# %%
pic_arr.shape
# Out:
# (1300, 1950, 3)

# %%
plt.imshow(pic_arr)
plt.show()

# %%
pic_red = pic_arr.copy()
pic_red[:,:,1] = 0
pic_red[:,:,2] = 0

pic_green = pic_arr.copy()
pic_green[:,:,0] = 0
pic_green[:,:,2] = 0

pic_blue = pic_arr.copy()
pic_blue[:,:,1] = 0
pic_blue[:,:,0] = 0

# %%
plt.imshow(pic_red)
plt.show()
plt.imshow(pic_green)
plt.show()
plt.imshow(pic_blue)
plt.show()

# %%
pic_red = pic_arr.copy()
# RED MAPPINGS -  0 (NO COLOR) 255 (FULL COLOR)
plt.imshow(pic_red[:,:,0], cmap='gray')
plt.show()

# %%
pic_red[:,:,0]
# Out:
# array([[95, 97, 98, ..., 25, 25, 25],
#        [95, 96, 96, ..., 25, 25, 25],
#        [95, 94, 94, ..., 25, 25, 25],
#        ...,
#        [19, 20, 20, ..., 23, 24, 24],
#        [20, 20, 19, ..., 23, 24, 24],
#        [20, 19, 19, ..., 23, 24, 24]], dtype=uint8)
